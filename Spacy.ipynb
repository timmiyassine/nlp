# %% [markdown]
# # spaCy

# %% [markdown]
# ### Load library

# %%
import spacy
from spacy.lang.ar import *

# %%
# !pip install spacy
# Out:
# Requirement already satisfied: spacy in c:\users\timmi\anaconda3\lib\site-packages (3.1.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\timmi\anaconda3\lib\site-packages (from spacy) (2.0.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\timmi\anaconda3\lib\site-packages (from spacy) (2.24.0)
# Requirement already satisfied: thinc<8.1.0,>=8.0.7 in c:\users\timmi\anaconda3\lib\site-packages (from spacy) (8.0.7)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in c:\users\timmi\anaconda3\lib\site-packages (from spacy) (2.4.1)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\timmi\anaconda3\lib\site-packages (from spacy) (1.18.5)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\timmi\anaconda3\lib\site-packages (from spacy) (3.0.5)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.4 in c:\users\timmi\anaconda3\lib\site-packages (from spacy) (2.0.4)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in c:\users\timmi\anaconda3\lib\site-packages (from spacy) (0.8.2)
# Requirement already satisfied: pathy>=0.3.5 in c:\users\timmi\anaconda3\lib\site-packages (from spacy) (0.6.0)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in c:\users\timmi\anaconda3\lib\site-packages (from spacy) (0.7.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\timmi\anaconda3\lib\site-packages (from spacy) (4.47.0)
# Requirement already satisfied: jinja2 in c:\users\timmi\anaconda3\lib\site-packages (from spacy) (2.11.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.7 in c:\users\timmi\anaconda3\lib\site-packages (from spacy) (3.0.8)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in c:\users\timmi\anaconda3\lib\site-packages (from spacy) (1.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\timmi\anaconda3\lib\site-packages (from spacy) (20.4)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in c:\users\timmi\anaconda3\lib\site-packages (from spacy) (0.3.2)
# Requirement already satisfied: setuptools in c:\users\timmi\anaconda3\lib\site-packages (from spacy) (49.2.0.post20200714)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\timmi\anaconda3\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\timmi\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.25.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\timmi\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\timmi\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\timmi\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in c:\users\timmi\anaconda3\lib\site-packages (from pathy>=0.3.5->spacy) (5.1.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\timmi\anaconda3\lib\site-packages (from jinja2->spacy) (1.1.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\timmi\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy) (3.10.0.0)
# Requirement already satisfied: six in c:\users\timmi\appdata\roaming\python\python38\site-packages (from packaging>=20.0->spacy) (1.15.0)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\timmi\anaconda3\lib\site-packages (from packaging>=20.0->spacy) (2.4.7)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in c:\users\timmi\anaconda3\lib\site-packages (from typer<0.4.0,>=0.3.0->spacy) (7.1.2)

# %%
import spacy
from spacy.lang.ar import *

# %%
Eng_t = """Perhaps one of the most significant advances made by Arabic mathematics began at this time with the work of al-Khwarizmi, namely the beginnings of algebra. It is important to understand just how significant this new idea was. It was a revolutionary move away from the Greek concept of mathematics which was essentially geometry. Algebra was a unifying theory which allowedrational numbers,irrational numbers, geometrical magnitudes, etc., to all be treated as \"algebraic objects\". It gave mathematics a whole new development path so much broader in concept to that which had existed before, and provided a vehicle for future development of the subject. Another important aspect of the introduction of algebraic ideas was that it allowed mathematics to be applied to itselfin a way which had not happened before."""

# %%
Eng_t
# Out:
# 'Perhaps one of the most significant advances made by Arabic mathematics began at this time with the work of al-Khwarizmi, namely the beginnings of algebra. It is important to understand just how significant this new idea was. It was a revolutionary move away from the Greek concept of mathematics which was essentially geometry. Algebra was a unifying theory which allowedrational numbers,irrational numbers, geometrical magnitudes, etc., to all be treated as "algebraic objects". It gave mathematics a whole new development path so much broader in concept to that which had existed before, and provided a vehicle for future development of the subject. Another important aspect of the introduction of algebraic ideas was that it allowed mathematics to be applied to itselfin a way which had not happened before.'

# %% [markdown]
# ### Load Data

# %%
Ar_t ="""ربما كانت أحد أهم التطورات التي قامت بها الرياضيات العربية التي بدأت في هذا الوقت بعمل الخوارزمي وهي بدايات الجبر, ومن المهم فهم كيف كانت هذه الفكرة الجديدة مهمة, فقد كانت خطوة نورية بعيدا عن المفهوم اليوناني للرياضيات التي هي في جوهرها هندسة, الجبر کان نظرية موحدة تتيح الأعداد الكسرية والأعداد اللا كسرية, والمقادير الهندسية وغيرها, أن تتعامل على أنها أجسام جبرية, وأعطت الرياضيات ككل مسارا جديدا للتطور بمفهوم أوسع بكثير من الذي كان موجودا من قبل, وقم وسيلة للتنمية في هذا الموضوع مستقبلا. وجانب آخر مهم لإدخال أفكار الجبر وهو أنه سمح بتطبيق الرياضيات على نفسها بطريقة لم تحدث من قبل"""

# %%
Ar_t
# Out:
# 'ربما كانت أحد أهم التطورات التي قامت بها الرياضيات العربية التي بدأت في هذا الوقت بعمل الخوارزمي وهي بدايات الجبر, ومن المهم فهم كيف كانت هذه الفكرة الجديدة مهمة, فقد كانت خطوة نورية بعيدا عن المفهوم اليوناني للرياضيات التي هي في جوهرها هندسة, الجبر کان نظرية موحدة تتيح الأعداد الكسرية والأعداد اللا كسرية, والمقادير الهندسية وغيرها, أن تتعامل على أنها أجسام جبرية, وأعطت الرياضيات ككل مسارا جديدا للتطور بمفهوم أوسع بكثير من الذي كان موجودا من قبل, وقم وسيلة للتنمية في هذا الموضوع مستقبلا. وجانب آخر مهم لإدخال أفكار الجبر وهو أنه سمح بتطبيق الرياضيات على نفسها بطريقة لم تحدث من قبل'

# %% [markdown]
# ## Tokenization

# %%
# !python -m spacy download en_core_web_sm
# Out:
# Requirement already satisfied: en-core-web-sm==3.1.0 from https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.1.0/en_core_web_sm-3.1.0-py3-none-any.whl#egg=en_core_web_sm==3.1.0 in c:\users\timmi\anaconda3\lib\site-packages (3.1.0)
# Requirement already satisfied: spacy<3.2.0,>=3.1.0 in c:\users\timmi\anaconda3\lib\site-packages (from en-core-web-sm==3.1.0) (3.1.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.4 in c:\users\timmi\anaconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.0.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\timmi\anaconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (1.0.5)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in c:\users\timmi\anaconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.4.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.7 in c:\users\timmi\anaconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (3.0.8)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\timmi\anaconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (4.47.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\timmi\anaconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.24.0)
# Requirement already satisfied: pathy>=0.3.5 in c:\users\timmi\anaconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (0.6.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in c:\users\timmi\anaconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (1.8.2)
# Requirement already satisfied: thinc<8.1.0,>=8.0.7 in c:\users\timmi\anaconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (8.0.7)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\timmi\anaconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (3.0.5)
# Requirement already satisfied: setuptools in c:\users\timmi\anaconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (49.2.0.post20200714)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in c:\users\timmi\anaconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (0.7.4)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\timmi\anaconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (1.18.5)
# Requirement already satisfied: jinja2 in c:\users\timmi\anaconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.11.2)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in c:\users\timmi\anaconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (0.3.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\timmi\anaconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (20.4)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in c:\users\timmi\anaconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (0.8.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\timmi\anaconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.0.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\timmi\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\timmi\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\timmi\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\timmi\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (1.25.9)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in c:\users\timmi\anaconda3\lib\site-packages (from pathy>=0.3.5->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (5.1.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\timmi\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (3.10.0.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\timmi\anaconda3\lib\site-packages (from jinja2->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (1.1.1)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in c:\users\timmi\anaconda3\lib\site-packages (from typer<0.4.0,>=0.3.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (7.1.2)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\timmi\anaconda3\lib\site-packages (from packaging>=20.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.4.7)
# Requirement already satisfied: six in c:\users\timmi\appdata\roaming\python\python38\site-packages (from packaging>=20.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (1.15.0)
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
nlp = spacy.load("en_core_web_sm")

# %%
doc_ar = Arabic()
doc_ar = nlp(Ar_t)

# %%
doc_en = nlp(Eng_t)

# %%
for token in doc_ar:
    print(token.text)
    
for token in doc_en:
    print(token.text)
# Out:
# ربما
# كانت
# أحد
# أهم
# التطورات
# التي
# قامت
# بها
# الرياضيات
# العربية
# التي
# بدأت
# في
# هذا
# الوقت
# بعمل
# الخوارزمي
# وهي
# بدايات
# الجبر
# ,
# ومن
# المهم
# فهم
# كيف
# كانت
# هذه
# الفكرة
# الجديدة
# مهمة
# ,
# فقد
# كانت
# خطوة
# نورية
# بعيدا
# عن
# المفهوم
# اليوناني
# للرياضيات
# التي
# هي
# في
# جوهرها
# هندسة
# ,
# الجبر
# کان
# نظرية
# موحدة
# تتيح
# الأعداد
# الكسرية
# والأعداد
# اللا
# كسرية
# ,
# والمقادير
# الهندسية
# وغيرها
# ,
# أن
# تتعامل
# على
# أنها
# أجسام
# جبرية
# ,
# وأعطت
# الرياضيات
# ككل
# مسارا
# جديدا
# للتطور
# بمفهوم
# أوسع
# بكثير
# من
# الذي
# كان
# موجودا
# من
# قبل
# ,
# وقم
# وسيلة
# للتنمية
# في
# هذا
# الموضوع
# مستقبلا
# .
# وجانب
# آخر
# مهم
# لإدخال
# أفكار
# الجبر
# وهو
# أنه
# سمح
# بتطبيق
# الرياضيات
# على
# نفسها
# بطريقة
# لم
# تحدث
# من
# قبل
# Perhaps
# one
# of
# the
# most
# significant
# advances
# made
# by
# Arabic
# mathematics
# began
# at
# this
# time
# with
# the
# work
# of
# al
# -
# Khwarizmi
# ,
# namely
# the
# beginnings
# of
# algebra
# .
# It
# is
# important
# to
# understand
# just
# how
# significant
# this
# new
# idea
# was
# .
# It
# was
# a
# revolutionary
# move
# away
# from
# the
# Greek
# concept
# of
# mathematics
# which
# was
# essentially
# geometry
# .
# Algebra
# was
# a
# unifying
# theory
# which
# allowedrational
# numbers
# ,
# irrational
# numbers
# ,
# geometrical
# magnitudes
# ,
# etc
# .
# ,
# to
# all
# be
# treated
# as
# "
# algebraic
# objects
# "
# .
# It
# gave
# mathematics
# a
# whole
# new
# development
# path
# so
# much
# broader
# in
# concept
# to
# that
# which
# had
# existed
# before
# ,
# and
# provided
# a
# vehicle
# for
# future
# development
# of
# the
# subject
# .
# Another
# important
# aspect
# of
# the
# introduction
# of
# algebraic
# ideas
# was
# that
# it
# allowed
# mathematics
# to
# be
# applied
# to
# itselfin
# a
# way
# which
# had
# not
# happened
# before
# .

# %% [markdown]
# ### Part-of-speech tags and dependencies

# %%
for token in doc_en:
    print(token.text, token.pos_, token.tag_)
# Out:
# Perhaps ADV RB
# one NUM CD
# of ADP IN
# the DET DT
# most ADV RBS
# significant ADJ JJ
# advances NOUN NNS
# made VERB VBN
# by ADP IN
# Arabic ADJ JJ
# mathematics NOUN NNS
# began VERB VBD
# at ADP IN
# this DET DT
# time NOUN NN
# with ADP IN
# the DET DT
# work NOUN NN
# of ADP IN
# al PROPN NNP
# - PUNCT HYPH
# Khwarizmi PROPN NNP
# , PUNCT ,
# namely ADV RB
# the DET DT
# beginnings NOUN NNS
# of ADP IN
# algebra PROPN NNP
# . PUNCT .
# It PRON PRP
# is AUX VBZ
# important ADJ JJ
# to PART TO
# understand VERB VB
# just ADV RB
# how ADV WRB
# significant ADJ JJ
# this DET DT
# new ADJ JJ
# idea NOUN NN
# was AUX VBD
# . PUNCT .
# It PRON PRP
# was AUX VBD
# a DET DT
# revolutionary ADJ JJ
# move NOUN NN
# away ADV RB
# from ADP IN
# the DET DT
# Greek ADJ JJ
# concept NOUN NN
# of ADP IN
# mathematics NOUN NNS
# which DET WDT
# was VERB VBD
# essentially ADV RB
# geometry NOUN NN
# . PUNCT .
# Algebra PROPN NNP
# was AUX VBD
# a DET DT
# unifying ADJ JJ
# theory NOUN NN
# which DET WDT
# allowedrational ADJ JJ
# numbers NOUN NNS
# , PUNCT ,
# irrational ADJ JJ
# numbers NOUN NNS
# , PUNCT ,
# geometrical ADJ JJ
# magnitudes NOUN NNS
# , PUNCT ,
# etc X FW
# . X FW
# , PUNCT ,
# to ADP IN
# all DET DT
# be AUX VB
# treated VERB VBN
# as ADP IN
# " PUNCT ``
# algebraic ADJ JJ
# objects NOUN NNS
# " PUNCT ''
# . PUNCT .
# It PRON PRP
# gave VERB VBD
# mathematics NOUN NNS
# a DET DT
# whole ADJ JJ
# new ADJ JJ
# development NOUN NN
# path NOUN NN
# so ADV RB
# much ADV RB
# broader ADJ JJR
# in ADP IN
# concept NOUN NN
# to ADP IN
# that DET DT
# which DET WDT
# had AUX VBD
# existed VERB VBN
# before ADV RB
# , PUNCT ,
# and CCONJ CC
# provided VERB VBD
# a DET DT
# vehicle NOUN NN
# for ADP IN
# future ADJ JJ
# development NOUN NN
# of ADP IN
# the DET DT
# subject NOUN NN
# . PUNCT .
# Another DET DT
# important ADJ JJ
# aspect NOUN NN
# of ADP IN
# the DET DT
# introduction NOUN NN
# of ADP IN
# algebraic ADJ JJ
# ideas NOUN NNS
# was AUX VBD
# that SCONJ IN
# it PRON PRP
# allowed VERB VBD
# mathematics NOUN NNS
# to PART TO
# be AUX VB
# applied VERB VBN
# to PART TO
# itselfin VERB VB
# a DET DT
# way NOUN NN
# which DET WDT
# had AUX VBD
# not PART RB
# happened VERB VBN
# before ADV RB
# . PUNCT .

# %%
for token in doc_ar:
    print(token.text, token.pos_)
# Out:
# ربما PROPN
# كانت PROPN
# أحد PROPN
# أهم PROPN
# التطورات VERB
# التي PROPN
# قامت VERB
# بها NOUN
# الرياضيات ADJ
# العربية NOUN
# التي NOUN
# بدأت VERB
# في ADP
# هذا ADJ
# الوقت PROPN
# بعمل PROPN
# الخوارزمي PROPN
# وهي PROPN
# بدايات NOUN
# الجبر NOUN
# , PUNCT
# ومن PROPN
# المهم NOUN
# فهم PROPN
# كيف PROPN
# كانت PROPN
# هذه PROPN
# الفكرة PROPN
# الجديدة PROPN
# مهمة PROPN
# , PUNCT
# فقد PROPN
# كانت PROPN
# خطوة PROPN
# نورية VERB
# بعيدا NOUN
# عن PROPN
# المفهوم PROPN
# اليوناني PROPN
# للرياضيات PROPN
# التي PROPN
# هي PROPN
# في INTJ
# جوهرها PROPN
# هندسة PROPN
# , PUNCT
# الجبر PROPN
# کان PROPN
# نظرية PROPN
# موحدة PROPN
# تتيح PROPN
# الأعداد PROPN
# الكسرية NOUN
# والأعداد NOUN
# اللا NOUN
# كسرية VERB
# , PUNCT
# والمقادير PROPN
# الهندسية PROPN
# وغيرها PROPN
# , PUNCT
# أن PRON
# تتعامل VERB
# على PROPN
# أنها PROPN
# أجسام PROPN
# جبرية NOUN
# , PUNCT
# وأعطت PROPN
# الرياضيات ADJ
# ككل VERB
# مسارا NOUN
# جديدا NOUN
# للتطور VERB
# بمفهوم NOUN
# أوسع NOUN
# بكثير PROPN
# من PROPN
# الذي PROPN
# كان PROPN
# موجودا PROPN
# من NOUN
# قبل NOUN
# , PUNCT
# وقم PRON
# وسيلة VERB
# للتنمية ADJ
# في ADP
# هذا PROPN
# الموضوع PROPN
# مستقبلا PROPN
# . PUNCT
# وجانب PROPN
# آخر VERB
# مهم NOUN
# لإدخال NOUN
# أفكار NOUN
# الجبر VERB
# وهو PROPN
# أنه PROPN
# سمح PROPN
# بتطبيق PROPN
# الرياضيات PROPN
# على PROPN
# نفسها PROPN
# بطريقة PROPN
# لم PROPN
# تحدث PROPN
# من DET
# قبل NOUN

# %% [markdown]
# ### Visualizing the dependency parse

# %%
from spacy import displacy
displacy.serve(doc_en, style="dep")
# Out:
# C:\Users\TIMMI\anaconda3\lib\site-packages\spacy\displacy\__init__.py:97: UserWarning: [W011] It looks like you're calling displacy.serve from within a Jupyter notebook or a similar environment. This likely means you're already running a local web server, so there's no need to make displaCy start another one. Instead, you should be able to replace displacy.serve with displacy.render to show the visualization.
#   warnings.warn(Warnings.W011)
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="b0d1713abeba495e9df614e09d3e1165-0" class="displacy" width="22625" height="1187.0" direction="ltr" style="max-width: none; height: 1187.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Perhaps</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">one</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">most</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">significant</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">advances</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">made</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">by</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">Arabic</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">mathematics</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">began</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">at</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">this</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">time</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">with</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">work</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">al-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">Khwarizmi,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">namely</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">beginnings</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">algebra.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">It</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">important</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tsp
# Using the 'dep' visualizer
# Serving on http://0.0.0.0:5000 ...

# %% [markdown]
# ### Lemmatization

# %%
for token in doc_ar:
    print(token.text, token.pos_, token.lemma_)
# Out:
# ربما PROPN ربما
# كانت PROPN كانت
# أحد PROPN أحد
# أهم PROPN أهم
# التطورات VERB التطورات
# التي PROPN التي
# قامت VERB قامت
# بها NOUN بها
# الرياضيات ADJ الرياضيات
# العربية NOUN العربية
# التي NOUN التي
# بدأت VERB بدأت
# في ADP في
# هذا ADJ هذا
# الوقت PROPN الوقت
# بعمل PROPN بعمل
# الخوارزمي PROPN الخوارزمي
# وهي PROPN وهي
# بدايات NOUN بدايات
# الجبر NOUN الجبر
# , PUNCT ,
# ومن PROPN ومن
# المهم NOUN المهم
# فهم PROPN فهم
# كيف PROPN كيف
# كانت PROPN كانت
# هذه PROPN هذه
# الفكرة PROPN الفكرة
# الجديدة PROPN الجديدة
# مهمة PROPN مهمة
# , PUNCT ,
# فقد PROPN فقد
# كانت PROPN كانت
# خطوة PROPN خطوة
# نورية VERB نورية
# بعيدا NOUN بعيدا
# عن PROPN عن
# المفهوم PROPN المفهوم
# اليوناني PROPN اليوناني
# للرياضيات PROPN للرياضيات
# التي PROPN التي
# هي PROPN هي
# في INTJ في
# جوهرها PROPN جوهرها
# هندسة PROPN هندسة
# , PUNCT ,
# الجبر PROPN الجبر
# کان PROPN کان
# نظرية PROPN نظرية
# موحدة PROPN موحدة
# تتيح PROPN تتيح
# الأعداد PROPN الأعداد
# الكسرية NOUN الكسرية
# والأعداد NOUN والأعداد
# اللا NOUN اللا
# كسرية VERB كسرية
# , PUNCT ,
# والمقادير PROPN والمقادير
# الهندسية PROPN الهندسية
# وغيرها PROPN وغيرها
# , PUNCT ,
# أن PRON أن
# تتعامل VERB تتعامل
# على PROPN على
# أنها PROPN أنها
# أجسام PROPN أجسام
# جبرية NOUN جبرية
# , PUNCT ,
# وأعطت PROPN وأعطت
# الرياضيات ADJ الرياضيات
# ككل VERB ككل
# مسارا NOUN مسارا
# جديدا NOUN جديدا
# للتطور VERB للتطور
# بمفهوم NOUN بمفهوم
# أوسع NOUN أوسع
# بكثير PROPN بكثير
# من PROPN من
# الذي PROPN الذي
# كان PROPN كان
# موجودا PROPN موجودا
# من NOUN من
# قبل NOUN قبل
# , PUNCT ,
# وقم PRON وقم
# وسيلة VERB وسيلة
# للتنمية ADJ للتنمية
# في ADP في
# هذا PROPN هذا
# الموضوع PROPN الموضوع
# مستقبلا PROPN مستقبلا
# . PUNCT .
# وجانب PROPN وجانب
# آخر VERB آخر
# مهم NOUN مهم
# لإدخال NOUN لإدخال
# أفكار NOUN أفكار
# الجبر VERB الجبر
# وهو PROPN وهو
# أنه PROPN أنه
# سمح PROPN سمح
# بتطبيق PROPN بتطبيق
# الرياضيات PROPN الرياضيات
# على PROPN على
# نفسها PROPN نفسها
# بطريقة PROPN بطريقة
# لم PROPN لم
# تحدث PROPN تحدث
# من DET من
# قبل NOUN قبل

# %% [markdown]
# ### Chunking

# %%
for chunk in doc_en.noun_chunks:
    print(chunk.label_, chunk)
# Out:
# NP the most significant advances
# NP Arabic mathematics
# NP this time
# NP the work
# NP al-Khwarizmi
# NP namely the beginnings
# NP algebra
# NP It
# NP this new idea
# NP It
# NP a revolutionary move
# NP the Greek concept
# NP mathematics
# NP essentially geometry
# NP Algebra
# NP a unifying theory
# NP allowedrational numbers
# NP irrational numbers
# NP geometrical magnitudes
# NP "algebraic objects
# NP It
# NP mathematics
# NP a whole new development path
# NP concept
# NP a vehicle
# NP future development
# NP the subject
# NP Another important aspect
# NP the introduction
# NP algebraic ideas
# NP it
# NP mathematics
# NP a way

# %%
for token in doc_en:
    if token.pos_ == "VERB":
        print(token.tag_, token.lemma_)
# Out:
# VBN make
# VBD begin
# VB understand
# VBD be
# VBN treat
# VBD give
# VBN exist
# VBD provide
# VBD allow
# VBN apply
# VB itselfin
# VBN happen

# %% [markdown]
# ### Named entities

# %%
for ent in doc_en.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
# Out:
# Arabic mathematics 53 71 NORP
# al-Khwarizmi 108 120 GPE
# Greek 268 273 NORP

# %% [markdown]
# ### Dependencies

# %%
# %load_ext watermark

# %%
# %watermark -p spacy
# Out:
# spacy: 3.1.0
